# %% [markdown]
# Sagari Datta
#
# MUSA620/Data Wrangling
#
# Spring 2019
#
# PROJECT DESCRIPTION:
# For this project, the political affiliation of the voters in Philadelphia for the 2016 general election were analyzed. The voter data was obtained from Open Data Philly.

# %%
#import libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
#read csv
election16 = pd.read_csv("./voter_turnout_general_election_2016.csv")
#check what's in the data
election16.head()
# Out:
#                 election election_date  precinct_code precinct_description  \
# 0  2016 GENERAL ELECTION     11/8/2016           2145   PHILA WD 21 DIV 45
# 1  2016 GENERAL ELECTION     11/8/2016           2215   PHILA WD 22 DIV 15
# 2  2016 GENERAL ELECTION     11/8/2016           2228   PHILA WD 22 DIV 28
# 3  2016 GENERAL ELECTION     11/8/2016           4045   PHILA WD 40 DIV 45
# 4  2016 GENERAL ELECTION     11/8/2016           5842   PHILA WD 58 DIV 42
#
#   political_party  voter_count
# 0            NONE            2
# 1            NONE            1
# 2            NONE            1
# 3            NONE            1
# 4            NONE            5

# %%
#check size/how many rows in the dataframe
len(election16)
# Out:
# 13910

# %%
#reformat the case of the letters
election16['political_party']= election16['political_party'].str.title() 
election16.head()
# Out:
#                 election election_date  precinct_code precinct_description  \
# 0  2016 GENERAL ELECTION     11/8/2016           2145   PHILA WD 21 DIV 45
# 1  2016 GENERAL ELECTION     11/8/2016           2215   PHILA WD 22 DIV 15
# 2  2016 GENERAL ELECTION     11/8/2016           2228   PHILA WD 22 DIV 28
# 3  2016 GENERAL ELECTION     11/8/2016           4045   PHILA WD 40 DIV 45
# 4  2016 GENERAL ELECTION     11/8/2016           5842   PHILA WD 58 DIV 42
#
#   political_party  voter_count
# 0            None            2
# 1            None            1
# 2            None            1
# 3            None            1
# 4            None            5

# %%
#create a dataframe with political parties and voter count summaries
voter_party = election16.groupby(['political_party'])['voter_count'].sum()
voter_party = voter_party.reset_index()
voter_party.head()
# Out:
#              political_party  voter_count
# 0                    Adarian           29
# 1                   American           31
# 2       American Independent           10
# 3             American Labor            2
# 4  American Solidarity Party            2

# %%
#sort the voter count
voter_party = voter_party.sort_values(by='voter_count') 
voter_party = voter_party.reset_index()
voter_party.head()
# Out:
#    index        political_party  voter_count
# 0    106             _Democracy            1
# 1     30         Green Democrat            1
# 2     32  Green Party Of The Us            1
# 3     34        Hillery Clinton            1
# 4     35           Humanitarian            1

# %%
#create a vote percentage column
voter_party['voteCount_pct'] = round((voter_party.voter_count / voter_party.voter_count.sum()) * 100)
voter_party.head()
# Out:
#    index        political_party  voter_count  voteCount_pct
# 0    106             _Democracy            1            0.0
# 1     30         Green Democrat            1            0.0
# 2     32  Green Party Of The Us            1            0.0
# 3     34        Hillery Clinton            1            0.0
# 4     35           Humanitarian            1            0.0

# %%
#select only democratic, republican and no affiliation vote counts
main_parties = voter_party.iloc[[104,105,106]]
main_parties
# Out:
#      index political_party  voter_count  voteCount_pct
# 104     65  No Affiliation        43584            6.0
# 105     87      Republican        82947           11.0
# 106     21      Democratic       576953           80.0

# %%
#bar plot the main parties dataframe - using matplotlib (Part1)
plt.bar(main_parties['political_party'], 
        main_parties['voteCount_pct'], 
        align = 'center', 
        color = ('#aaadaf', '#D62728', '#0b2d51'))

plt.title('Vote count % by political affiliation in Philadelphia in 2016 general elections', size=12)
plt.xlabel('Political Affiliation', size=14)
plt.ylabel('Voter count %', size=14)
plt.tick_params(labelsize=12)

# %% [markdown]
# Main conclusion:
# The plot above shows that Philadelphia voted overwhelmingly democratic in the 2016 general elections

# %%
#import library for part 2 
import seaborn as sns

# %%
#select top 3 political affiliations  
top_3 = ['Democratic', 
              'Republican', 
              'No Affiliation']

select_party = election16['political_party'].isin(top_3)
top3 = election16.loc[select_party]
#top3

# %%
#make boxen plots using seaborn (plot for part 2)
my_pal = {"Democratic": "#0b2d51", "Republican": "#D62728", "No Affiliation":"#aaadaf"}
plot2 = sns.boxenplot( x=top3["political_party"], y=top3["voter_count"], palette=my_pal)
plot2.axes.set_title("Box plots showing political affiliation in Philadelphia for the 2016 general elections",fontsize=12)
plot2.set_ylabel("Voter count Philadelphia",fontsize=14)
plot2.set_xlabel("Political affiliation",fontsize=14)
plot2.tick_params(labelsize=10)

# %% [markdown]
# Motivation:
# The motivation for using a box plot was to find out what the median vote counts and the distribution of vote counts look like for the top three categories namely Democratic, Republican and No affiliation. I selected the boxen plot since it looks visually/stylistically different from the regular box plots and therefore a bit more interesting to look at.
# Main conclusion:
# The median voter count in Philadelphia for the Democratic party is considerably higher than the Republican party for the 2016 general election.

# %%
#import altair library for part 3
import altair as alt
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
#groupby political party and precinct code
voter_party_df3 = top3.groupby(['political_party', 'precinct_code'])['voter_count'].sum()
voter_party_df3 = voter_party_df3.reset_index()
#voter_party_df3.head()

# %%
#groupby precinct only
prec_df3 = top3.groupby(['precinct_code'])['voter_count'].sum()
prec_df3 = prec_df3.reset_index()
#prec_df3.head()

# %%
#filter for 10 largest precincts in terms of votes counted
largest_prec = prec_df3.nlargest(10, 'voter_count')
largest_prec = largest_prec.reset_index()
largest_prec
# Out:
#    index  precinct_code  voter_count
# 0    111            521         1412
# 1    668           3017         1161
# 2    165            805         1126
# 3    107            517         1123
# 4    186            826         1092
# 5    175            815         1086
# 6     91            501         1030
# 7    184            824         1002
# 8    102            512          984
# 9    614           2722          981

# %%
#select largest precincts
select_prec = voter_party_df3['precinct_code'].isin(largest_prec['precinct_code'])
topPrec = voter_party_df3.loc[select_prec]
topPrec = topPrec.reset_index() 

topPrec
# Out:
#     index political_party  precinct_code  voter_count
# 0      91      Democratic            501          729
# 1     102      Democratic            512          706
# 2     107      Democratic            517          865
# 3     111      Democratic            521          937
# 4     165      Democratic            805          724
# 5     175      Democratic            815          727
# 6     184      Democratic            824          702
# 7     186      Democratic            826          800
# 8     614      Democratic           2722          709
# 9     668      Democratic           3017          823
# 10   1777  No Affiliation            501          123
# 11   1788  No Affiliation            512          125
# 12   1793  No Affiliation            517          133
# 13   1797  No Affiliation            521          236
# 14   1851  No Affiliation            805          184
# 15   1861  No Affiliation            815          155
# 16   1870  No Affiliation            824          132
# 17   1872  No Affiliation            826          141
# 18   2300  No Affiliation           2722          124
# 19   2353  No Affiliation           3017          167
# 20   3462      Republican            501          178
# 21   3473      Republican            512          153
# 22   3478      Republican            517          125
# 23   3482      Republican            521          239
# 24   3536      Republican            805          218
# 25   3546      Republican            815          204
# 26   3555      Republican            824          168
# 27   3557      Republican            826          151
# 28   3983      Republican           2722          148
# 29   4037      Republican           3017          171

# %%
# initialize the chart with the data
chart = alt.Chart(topPrec)

# define what kind of marks to use
chart = chart.mark_circle(size=60)

# encode the visual channels
chart = chart.encode(
    x=alt.X('precinct_code:N', axis=alt.Axis(title='Precinct code')),
    y=alt.Y('voter_count:Q', axis=alt.Axis(title='Voter count in 2016')),
    color='political_party',
    tooltip=['political_party', "precinct_code", "voter_count"]
)

# make the chart interactive
#chart.interactive()

# %%
print(chart.to_json())
# Out:
# {
#   "$schema": "https://vega.github.io/schema/vega-lite/v3.2.1.json",
#   "config": {
#     "mark": {
#       "tooltip": null
#     },
#     "view": {
#       "height": 300,
#       "width": 400
#     }
#   },
#   "data": {
#     "name": "data-1e2f9c9f572780836e9191b597ce2a6a"
#   },
#   "datasets": {
#     "data-1e2f9c9f572780836e9191b597ce2a6a": [
#       {
#         "index": 91,
#         "political_party": "Democratic",
#         "precinct_code": 501,
#         "voter_count": 729
#       },
#       {
#         "index": 102,
#         "political_party": "Democratic",
#         "precinct_code": 512,
#         "voter_count": 706
#       },
#       {
#         "index": 107,
#         "political_party": "Democratic",
#         "precinct_code": 517,
#         "voter_count": 865
#       },
#       {
#         "index": 111,
#         "political_party": "Democratic",
#         "precinct_code": 521,
#         "voter_count": 937
#       },
#       {
#         "index": 165,
#         "political_party": "Democratic",
#         "precinct_code": 805,
#         "voter_count": 724
#       },
#       {
#         "index": 175,
#         "political_party": "Democratic",
#         "precinct_code": 815,
#         "voter_count": 727
#       },
#       {
#         "index": 184,
#         "political_party": "Democratic",
#         "precinct_code": 824,
#         "voter_count": 702
#       },
#       {
#         "index": 186,
#         "political_party": "Democratic",
#         "precinct_code": 826,
#         "voter_count": 800
#       },
#       {
#         "index": 614,
#         "political_party": "Democratic",
#         "precinct_code": 2722,
#         "voter_count": 709
#       },
#       {
#         "index": 668,
#         "political_party": "Democratic",
#         "precinct_code": 3017,
#         "voter_count": 823
#       },
#       {
#         "index": 1777,
#         "political_party": "No Affiliation",
#         "precinct_code": 501,
#         "voter_count": 123
#       },
#       {
#         "index": 1788,
#         "political_party": "No Affiliation",
#         "precinct_code": 512,
#         "voter_count": 125
#       },
#       {
#         "index": 1793,
#         "political_party": "No Affiliation",
#         "precinct_code": 517,
#         "voter_count": 133
#       },
#       {
#         "index": 1797,
#         "political_party": "No Affiliation",
#         "precinct_code": 521,
#         "voter_count": 236
#       },
#       {
#         "index": 1851,
#         "political_party": "No Affiliation",
#         "precinct_code": 805,
#         "voter_count": 184
#       },
#       {
#         "index": 1861,
#         "political_party": "No Affiliation",
#         "precinct_code": 815,
#         "voter_count": 155
#       },
#       {
#         "index": 1870,
#         "political_party": "No Affiliation",
#         "precinct_code": 824,
#         "voter_count": 132
#       },
#       {
#         "index": 1872,
#         "political_party": "No Affiliation",
#         "precinct_code": 826,
#         "voter_count": 141
#       },
#       {
#         "index": 2300,
#         "political_party": "No Affiliation",
#         "precinct_code": 2722,
#         "voter_count": 124
#       },
#       {
#         "index": 2353,
#         "political_party": "No Affiliation",
#         "precinct_code": 3017,
#         "voter_count": 167
#       },
#       {
#         "index": 3462,
#         "political_party": "Republican",
#         "precinct_code": 501,
#         "voter_count": 178
#       },
#       {
#         "index": 3473,
#         "political_party": "Republican",
#         "precinct_code": 512,
#         "voter_count": 153
#       },
#       {
#         "index": 3478,
#         "political_party": "Republican",
#         "precinct_code": 517,
#         "voter_count": 125
#       },
#       {
#         "index": 3482,
#         "political_party": "Republican",
#         "precinct_code": 521,
#         "voter_count": 239
#       },
#       {
#         "index": 3536,
#         "political_party": "Republican",
#         "precinct_code": 805,
#         "voter_count": 218
#       },
#       {
#         "index": 3546,
#         "political_party": "Republican",
#         "precinct_code": 815,
#         "voter_count": 204
#       },
#       {
#         "index": 3555,
#         "political_party": "Republican",
#         "precinct_code": 824,
#         "voter_count": 168
#       },
#       {
#         "index": 3557,
#         "political_party": "Republican",
#         "precinct_code": 826,
#         "voter_count": 151
#       },
#       {
#         "index": 3983,
#         "political_party": "Republican",
#         "precinct_code": 2722,
#         "voter_count": 148
#       },
#       {
#         "index": 4037,
#         "political_party": "Republican",
#         "precinct_code": 3017,
#         "voter_count": 171
#       }
#     ]
#   },
#   "encoding": {
#     "color": {
#       "field": "political_party",
#       "type": "nominal"
#     },
#     "tooltip": [
#       {
#         "field": "political_party",
#         "type": "nominal"
#       },
#       {
#         "field": "precinct_code",
#         "type": "quantitative"
#       },
#       {
#         "field": "voter_count",
#         "type": "quantitative"
#       }
#     ],
#     "x": {
#       "axis": {
#         "title": "Precinct code"
#       },
#       "field": "precinct_code",
#       "type": "nominal"
#     },
#     "y": {
#       "axis": {
#         "title": "Voter count in 2016"
#       },
#       "field": "voter_count",
#       "type": "quantitative"
#     }
#   },
#   "mark": {
#     "size": 60,
#     "type": "circle"
#   }
# }

# %%
chart.save("chart.html")

# %%
# Display IFrame in IPython 
#from IPython.display import IFrame
#IFrame('chart.html', width=500, height=375)

# %%
#plot for part 3 - transformation, brush selection and creation of 2-chart dashboard (transform_filter())
brush = alt.selection(type='interval')

# the top scatterplot
points = alt.Chart().mark_point().encode(
    x=alt.X('precinct_code:N', axis=alt.Axis(title='Precinct code')),
    y=alt.Y('voter_count:Q', axis=alt.Axis(title='Voter count in 2016')),
    color=alt.condition(brush, 'political_party:N', alt.value('lightgray'),scale=alt.Scale(
            domain=['Republican','No Affiliation', 'Democratic'],
            range=['#0b2d51','#aaadaf', '#D62728']))
).properties(
    selection=brush,
    width=800
)

# the bottom bar plot
bars = alt.Chart().mark_bar().encode(
    y=alt.Y('precinct_code:O', axis=alt.Axis(title='Precinct Code')),
    x=alt.X('sum(voter_count):Q', axis=alt.Axis(title='Sum of voter counts')),
    color='political_party:O',
    tooltip=['political_party','voter_count', 'precinct_code']
).transform_filter(
    brush.ref() # the filter transform uses the selection
                # to filter the input data to this chart
).properties(
width=800
)


chart = alt.vconcat(points, bars, data=topPrec) # vertical stacking
chart

# %% [markdown]
# Main conclusion:
# There seems to be some slight variation in the number of voters who voted Rebublican across the 10 precinct codes with the highest vote counts when compared to the vote counts for Democrats. Moreover, the vote counts for Republican and 'no affiliation' voters are very similar.
